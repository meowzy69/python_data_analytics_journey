# %% [markdown]
# # Module 2: Python Operators
#
# ## 📌 Objective
# In this module, I learned how Python performs calculations, comparisons, logical operations, assignments, membership checks, and identity checks using different types of operators.
#
# Operators are the building blocks of decision-making and problem-solving in Python. They are widely used in data analysis, automation, and software development.
#
# ---

# %% [markdown]
# # Types of Operators Covered
#
# 1. Arithmetic Operators
# 2. Comparison Operators
# 3. Logical Operators
# 4. Assignment Operators
# 5. Membership Operators
# 6. Identity Operators

# %% [markdown]
# # 1. Arithmetic Operators
#
# Arithmetic operators are used to perform mathematical calculations.
#
# | Operator | Meaning |
# |----------|---------|
# | + | Addition |
# | - | Subtraction |
# | * | Multiplication |
# | / | Division |
# | % | Modulus (Remainder) |
# | // | Floor Division |
# | ** | Exponent (Power) |

# %%
a = 15
b = 4

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Modulus:", a % b)
print("Floor Division:", a // b)
print("Exponent:", a ** b)
# Out:
# Addition: 19
# Subtraction: 11
# Multiplication: 60
# Division: 3.75
# Modulus: 3
# Floor Division: 3
# Exponent: 50625

# %% [markdown]
# ## Real-World Example
#
# A data analyst may use arithmetic operators to calculate:
#
# - Total Sales
# - Profit
# - Average Revenue
# - Growth Percentage
# - Remaining Stock

# %% [markdown]
# # 2. Comparison Operators
#
# Comparison operators compare two values and always return either **True** or **False**.
#
# | Operator | Meaning |
# |----------|---------|
# | == | Equal to |
# | != | Not Equal to |
# | > | Greater than |
# | < | Less than |
# | >= | Greater than or Equal to |
# | <= | Less than or Equal to |

# %%
x = 25
y = 15

print(x == y)
print(x != y)
print(x > y)
print(x < y)
print(x >= y)
print(x <= y)
# Out:
# False
# True
# True
# False
# True
# False

# %% [markdown]
# # 3. Logical Operators
#
# Logical operators are used to combine two or more conditions. They always return either **True** or **False**.
#
# | Operator | Meaning |
# |----------|---------|
# | and | Returns True if both conditions are True |
# | or | Returns True if at least one condition is True |
# | not | Reverses the Boolean value |

# %%
age = 20
has_id = True

print(age >= 18 and has_id)
print(age >= 18 or False)
print(not has_id)
# Out:
# True
# True
# False

# %% [markdown]
# ## Real-World Example
#
# Logical operators are commonly used when multiple conditions need to be checked.
#
# Examples:
# - User login verification
# - Scholarship eligibility
# - Customer eligibility
# - Employee attendance validation

# %% [markdown]
# # 4. Assignment Operators
#
# Assignment operators are used to assign values to variables.
#
# | Operator | Meaning |
# |----------|---------|
# | = | Assign |
# | += | Add and Assign |
# | -= | Subtract and Assign |
# | *= | Multiply and Assign |
# | /= | Divide and Assign |
# | %= | Modulus and Assign |
# | //= | Floor Divide and Assign |
# | **= | Exponent and Assign |

# %%
x = 20

x += 5
print("After += :", x)

x -= 3
print("After -= :", x)

x *= 2
print("After *= :", x)

x /= 2
print("After /= :", x)
# Out:
# After += : 25
# After -= : 22
# After *= : 44
# After /= : 22.0

# %% [markdown]
# ## Real-World Example
#
# Assignment operators make code shorter and easier to read.
#
# Instead of writing:
#
# total_sales = total_sales + sale
#
# We simply write:
#
# total_sales += sale

# %% [markdown]
# # 5. Membership Operators
#
# Membership operators check whether a value exists inside a sequence such as a list, tuple, set, dictionary, or string.
#
# | Operator | Meaning |
# |----------|---------|
# | in | Value exists |
# | not in | Value does not exist |

# %%
languages = ["Python", "SQL", "Excel"]

print("Python" in languages)
print("Java" in languages)

word = "Data Analytics"

print("Data" in word)
print("AI" not in word)
# Out:
# True
# False
# True
# True

# %% [markdown]
# # 6. Identity Operators
#
# Identity operators compare whether two variables refer to the **same object in memory**.
#
# | Operator | Meaning |
# |----------|---------|
# | is | Returns True if both variables refer to the same object |
# | is not | Returns True if both variables refer to different objects |

# %%
list1 = [1, 2, 3]
list2 = [1, 2, 3]
list3 = list1

print(list1 == list2)
print(list1 is list2)

print(list1 is list3)
print(list1 is not list2)
# Out:
# True
# False
# True
# True

# %% [markdown]
# ## Real-World Example
#
# Identity operators are most commonly used to check whether a variable is `None`.
#
# Example:
#
# ```python
# if data is None:
#     print("No data available")
# ```
#
# This is a common practice in Python programming and data analysis.

# %% [markdown]
# # Module Summary
#
# In this module, I learned six different categories of Python operators.
#
# - Arithmetic Operators
# - Comparison Operators
# - Logical Operators
# - Assignment Operators
# - Membership Operators
# - Identity Operators
#
# These operators are essential for performing calculations, comparing values, checking conditions, updating variables, searching collections, and comparing objects.

# %% [markdown]
# # Key Takeaways
#
# ✅ Arithmetic operators perform mathematical calculations.
#
# ✅ Comparison operators always return `True` or `False`.
#
# ✅ Logical operators combine multiple conditions.
#
# ✅ Assignment operators update variable values efficiently.
#
# ✅ Membership operators check whether a value exists inside a collection.
#
# ✅ Identity operators compare object identity rather than values.
#
# Mastering operators is essential before learning conditional statements (`if`, `elif`, `else`) and loops.

# %% [markdown]
# # Interview Tips
#
# - Know the difference between `=` and `==`.
# - Understand when to use `and`, `or`, and `not`.
# - Remember the difference between `==` (value comparison) and `is` (object identity).
# - Be comfortable using assignment operators like `+=` and `-=`.
# - Practice checking membership using `in` and `not in`.
