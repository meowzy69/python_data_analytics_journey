# %% [markdown]
# # Module 2 - Practice: Python Operators
#
# ## Objective
#
# Practice Python operators by solving coding questions of increasing difficulty.
#
# Topics Covered:
# - Arithmetic Operators
# - Comparison Operators
# - Logical Operators
# - Assignment Operators
# - Membership Operators
# - Identity Operators

# %%
num1 = 18
num2 = 7

# Print:
# Addition
# Subtraction
# Multiplication
# Division

print(num1+num2)
print(num1-num2)
print(num1*num2)
print(num1/num2)
# Out:
# 25
# 11
# 126
# 2.5714285714285716

# %%
number = 45

# Print the remainder when divided by 6

print(number % 6)
# Out:
# 3

# %%
number = 45

# Print the floor division result when divided by 6

print( number // 6)
# Out:
# 7

# %%
base = 5

# Print base raised to the power 3

print(base**3)
# Out:
# 125

# %%
age = 20

# Print whether age is greater than or equal to 18

print(age>=18)
# Out:
# True

# %%
marks = 75

# Print whether marks are less than 40

print(marks<40)
# Out:
# False

# %%
salary = 50000

salary += 10000

print(salary)
# Out:
# 60000

# %%
count = 15

count *= 4

print(count)
# Out:
# 60

# %%
languages = ["Python", "SQL", "Excel"]

# Check whether "SQL" exists

print("SQL" in languages)
# Out:
# True

# %%
word = "Data Analytics"

# Check whether "AI" is NOT present

print("AI" not in word)
# Out:
# True

# %%
age = 22
has_license = True

# Print whether the person is eligible to drive.
# (Age should be 18 or above AND must have a license.)

print(age>=18 and has_license,"eligible to drive")
# Out:
# True eligible to drive

# %%
temperature = 35

# Print whether the temperature is
# greater than 30 OR less than 10.

print(temperature > 30 or temperature < 10)
# Out:
# True

# %%
username = "admin"

# Print whether the username
# is NOT equal to "guest".

print(username != "guest")
# Out:
# True

# %%
items = ["Laptop", "Mouse", "Keyboard"]

# Check whether "Mouse" exists
# and "Monitor" does NOT exist.

print("Mouse" in items)
print("Monitor" not in items)
# Out:
# True
# True

# %%
score = 85

# Increase the score by 5
# Then print whether the new score
# is greater than or equal to 90.

score += 5

print(score >= 90)
# Out:
# True

# %%
word = "Python Programming"

# Check whether:
# "Python" exists
# AND
# "Java" does NOT exist.

print("Python" in word and "Java" not in word)
# Out:
# True

# %%
x = 12
y = 12

# Print:
# x == y
# x is y

print(x == y)
print(x is y)
# Out:
# True
# True

# %%
fruits = ["Apple", "Banana"]

new_fruits = fruits

# Print:
# fruits == new_fruits
# fruits is new_fruits

print(fruits == new_fruits)
print(fruits is new_fruits)
# Out:
# True
# True

# %%
salary = 40000

salary -= 5000

# Print whether salary
# is greater than 30000.

print(salary>30000)
# Out:
# True

# %%
age = 25
country = "India"

# Print whether:
#
# Age is greater than or equal to 18
# AND
# Country is "India"

print(age >= 18 and country == "India")
# Out:
# True

# %%
price = 1500
discount = 20

# Calculate the discount amount.
# Then calculate the final price after the discount.
# Print the final price.

discount_amt = price * (discount/100)
final_price = price - discount_amt
print(final_price)
# Out:
# 1200.0

# %%
username = "admin"
password = "python123"

# Check whether:
# Username is "admin"
# AND
# Password is "python123"

print(username == "admin" and password == "python123")
# Out:
# True

# %%
marks = 78

# Increase marks by 7.
# Then check whether marks are greater than or equal to 85.

marks += 7
print(marks >= 85)
# Out:
# True

# %%
courses = ["Python", "SQL", "Power BI", "Excel"]

# Check whether:
# "Python" exists
# AND
# "Tableau" does NOT exist.

print("Python" in courses and "Tableau" not in courses)
# Out:
# True

# %%
num = 17

# Check whether:
# num is greater than 10
# AND
# num is less than 20

print(num>10 and num<20)
# Out:
# True

# %%
salary = 55000
experience = 3

# Print whether the employee is eligible for promotion.

# Condition:
# Salary should be at least 50000
# AND
# Experience should be 2 years or more

print(salary>=50000 and experience>=2, "eligible for promotion")
# Out:
# True eligible for promotion

# %%
fruits = ["Apple", "Banana"]

basket = fruits

# Print:
# fruits == basket
# fruits is basket

# Then add "Orange" using basket.append()
# Print both variables again.

print(fruits == basket)
print(fruits is basket)

# unable to perform the .append() (cause didn't learn it yet)
# Out:
# True
# True

# %%
email = "student@gmail.com"

# Check whether:
# "@gmail.com" exists in the email
# AND
# "@yahoo.com" does NOT exist.

print("@gmail.com" in email and "@yahoo.com" not in email)
# Out:
# True

# %%
stock = 25

stock -= 5

# Check whether the remaining stock
# is greater than 15.

print(stock > 15)
# Out:
# True

# %%
name = "Chandrapal"
age = 22
skills = ["Python", "Excel", "SQL"]

# Print whether ALL of the following are True:
#
# Name is "Chandrapal"
# Age is greater than or equal to 18
# "Python" exists in skills
# "Power BI" does NOT exist in skills

print(name == "Chandrapal" and age >= 18 and "Python" in skills and "Power BI" not in skills)
# Out:
# True
