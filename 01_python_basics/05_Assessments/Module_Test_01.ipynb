# %% [markdown]
# # 📝 Module Test 1
#
# **Module:** Data Types
#
# **Date:** 15 July 2026
#
# **Time Taken:** 38 minutes
#
# **Score:** 96/100
#
# **Grade:** A+
#
# **Remarks:** Excellent understanding of data types, variables, input(), and type casting.
# Improve output formatting and continue using variables instead of hardcoded values.

# %%
# Question 1 (4 Marks)

# Explain the difference between:

# int
# float
# str
# bool

# Give one example of each.

# Ans 1 - integer is used for datatype that inlcudes whole no. for example the variable age has stored the interger dataype value(age = 23),used as int
# - float includes decimal type data unlike int where it uses whole number, float example is (price = 299.9)
# - string is a set of characters and it's mainly used to store character in double quotes without them you cannot store string datatypes, example name="chandrapal", known as str.
# - boolean is a type of data where it stores value in TRUE or FALSE i.e only two values for example Order_returned name variable only stores two value where it describes if a order is returned in true or false (order_returned = True)

# %% [markdown]
# Q.2 What is a variable?
# ans - A variable is a tag given to a value and it's datatype which describes the meaning of what is stored inside it , for example there's a variable name bucket in which the value "water" has been stored inside it (bucket = "water") and as it is stored in strings we can see the value stored in the variable bucket is a string datatype.

# %% [markdown]
# Q.2Why does input() always return a string?
# Ans - the reason is python uses default string datatype value in input() if the datatype isn't defined, for example age=input("enter any number") lets take the age 23 for now , so the output of this query will be in <class 'str'> cause we did not define the datatype
# but if we do age=int(input("enter any number")) we are defining the datatype to be an integer value

# %% [markdown]
# Q.4 What is type casting?
# ans - Type casting is where a user can type their own set of instructions...
# - The int(number) converts the number dataype temporary in integer whereas the number=int(number) converts the value permanently in integer datatype.

# %% [markdown]
# Q.5 What is the purpose of: 1.print() and 2. type()
# Ans - So the primary purpose of print() function is to print an output
# for example when we run print("hello") the output displayed in the result will be hello
# 2.type() - this function defines what type of data is stored inside a variable for example there is variable age=23 when we run the command print(type(age)) it will give us an output <class 'int'> where int is the datatype of variable age

# %% [markdown]
# 🟡 PART B – PREDICT THE OUTPUT (30 Marks)
# q.6
# name = "Rahul"
#
# print(name)
# print(type(name))
#
# Ans print(name) will print Rahul
# print(type(name)) will print <class 'str'>

# %% [markdown]
# Q.7
# age = "20"
#
# age = int(age)
#
# print(age + 10)
#
# ans - 30

# %% [markdown]
# Q.8
# price = "499.99"
#
# print(float(price))
# print(type(price))
#
# Ans. print(float(price)) will return 499.99
# print(type(price)) will return <class 'str'>

# %% [markdown]
# Q.9
# city = input("Enter city: ")
#
# print(city + " is beautiful")
#
# Ans - Delhi is beautiful

# %% [markdown]
# Q.10
# number = "50"
#
# print(number + "25")
#
# Ans - 5025

# %% [markdown]
# Question 11
#
# Write a program that:
#
# Takes the user's name
# Takes the user's age
# Converts age into an integer
# Prints:
# Hello Chandrapal
#
# You are 23 years old.

# %%
name = "Chandrapal"
age = 23
print("Hello",name)

print("You are",23,"years old")
# Out:
# Hello Chandrapal
# You are 23 years old

# %% [markdown]
# Question 12
#
# Write a program that:
#
# Takes two decimal numbers from the user
# Converts both into float
# Prints their sum

# %%
n1 = float(input("enter any number"))
n2 = float(input("enter any number"))
print(n1+n2)
# Out:
# 51.86

# %% [markdown]
# Question 13
#
# Create variables for:
#
# Product Name,
# Product Price,
# Product Quantity
#
# Print all three.

# %%
product_name = "Football"
product_price = 299.9
product_quantity = 10
print(product_name)
print(product_price)
print(product_quantity)
# not sure but i am thinking that for product price i have to multiply it with product quantity....?
# Out:
# Football
# 299.9
# 10

# %% [markdown]
# Question 14
#
# Create a Student Profile.
#
# Take input for:
#
# Name,
# College,
# Percentage
#
# Convert percentage into float.

# %%
name = input("enter student name")
college = input("enter college name")
percentage = float(input("enter percentage"))
print("-----Student Profile-----")
print("Name       :",name)
print("College    :",college)
print("Percentage :",percentage)
# Out:
# -----Student Profile-----
# Name       : Chandrapal
# College    : BSSS
# Percentage : 69.99

# %% [markdown]
# Question 15 ⭐
#
# Imagine you're working as a Data Analyst for a supermarket.
#
# Write a small billing program.
#
# Take input for:
#
# Customer Name,
# Product Name,
# Product Price
#
# Convert the price into float.

# %%
cus_name = input("enter customer name")
product_name = input("enter product name")
product_price = float(input("enter product price"))
print("-----BILL-----")
print("Customer   :",cus_name)
print("Product    :",product_name)
print("Price      :",product_price)
print("Thank you!")
# Out:
# -----BILL-----
# Customer   : CP
# Product    : Water bottle
# Price      : 12.99
# Thank you!
