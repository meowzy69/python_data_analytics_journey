# %% [markdown]
# # 📝 Module Test 2
#
# **Module:** Operators
#
# **Date:** 21 July 2026
#
# **Time Taken:** ______ minutes
#
# **Score:** ____ / 30
#
# **Grade:** _____
#
# **Remarks:** ____________________________________________

# %%
# Q1 (2 marks)

price = 4500
quantity = 3
discount = 10

# Calculate:
# Total Price
# Discount Amount
# Final Bill

# Print all three values.

total_price = price * quantity
dis_amt = price * (10/100)
final_bill = total_price - dis_amt

print("Total price =",total_price)
print("Discount amt =",dis_amt)
print("Final bill =",final_bill)
# Out:
# Total price = 13500
# Discount amt = 450.0
# Final bill = 13050.0

# %%
# q.2 (2 marks)

age = 19
has_id = True

# Print whether the person
# is eligible to enter an event.

# Conditions:
# Age should be at least 18
# AND
# Person must have an ID.

print("Eligible to enter an event =" ,age >=18 and has_id is True)
# Out:
# Eligible to enter an event = True

# %%
# q.3 (2 marks)

username = "student"
password = "python"

# Check whether BOTH values
# exactly match the given credentials.

print("student" in username and "python" in password)
# Out:
# True

# %%
# q.4 (2 marks)

courses = ["Python", "SQL", "Excel"]

# Print whether

# "Python" exists

# AND

# "Power BI" does NOT exist.

print("Python" in courses and "Power BI" not in courses)
# Out:
# True

# %%
# q.5 (2 marks)

salary = 35000

salary += 8000

# Print whether the updated
# salary is greater than 40000.

print(salary > 40000)
# Out:
# True

# %%
# q.6 (2 marks)

marks = 87

# Print whether
# marks are between
# 80 and 90.

print(marks >= 80 and marks <=90)
# Out:
# True

# %%
# q.7 (3 marks)

a = [1, 2]
b = [1, 2]
c = a

# Print

# a == b
# a is b

# a == c
# a is c

# Explain each output
# using comments.

print(a == b) 
# a==b is true because the values they includes are same and also they are both lists
print(a is b)
# a is b, is false because they are both different variables and it dosen't matter if their values are same , to make this condition true we have to do a = b this makes a is b condition true
print(a == c)
# a == c is true because we made both variables equal to each other
print(a is c)
# a is b true same reason we made both variables true with a = c
# Out:
# True
# False
# True
# True

# %%
# q.8 (2 marks)

wallet_balance = 20000
purchase_amount = 17500

# Increase wallet balance by ₹500.

# Deduct the purchase amount.

# Print the remaining balance.

wallet_balance += 500
remaining_bal = wallet_balance - purchase_amount

print(remaining_bal)
# Out:
# 3000

# %%
# q.9 (3 marks)

employee_name = "Rahul"

experience = 5

salary = 75000

skills = ["Python", "SQL", "Power BI"]

# Print whether ALL
# of the following are True:

# Employee name is Rahul

# Experience >= 5

# Salary > 70000

# Python exists

# Excel does NOT exist

print(employee_name == "Rahul" and experience >= 5 and salary > 70000 and "Python" in skills and "Excel" not in skills)
# Out:
# True

# %%
# q.10 (5 marks) Create a simple Movie Ticket Booking Checker

movie_name = input("enter movie name")
ticket_price = float(input("enter ticket price"))
tickets = int(input("enter tickets quantity"))
wallet_balance = float(input("enter wallet balance"))
available_formats = ["2D", "3D", "IMAX"]
selected_format = "3D"

# Your program should:

# Calculate the total ticket cost.
# Check whether the selected format is available.
# Check whether the wallet balance is enough.
# Print whether the booking can proceed using a logical expression.
# Deduct the amount from the wallet balance using an assignment operator.
# Print the remaining wallet balance.

total_ticket_cost = ticket_price * tickets
print("Total ticket cost =",total_ticket_cost)
print("3D is available =",selected_format in available_formats)
print("Enough wallet balance",wallet_balance >= total_ticket_cost)
print("Booking can proceed =",wallet_balance >= total_ticket_cost and selected_format in available_formats)

wallet_balance -= total_ticket_cost
print("Remaining balance =",wallet_balance)
# Out:
# Total ticket cost = 2000.0
# 3D is available = True
# Enough wallet balance True
# Booking can proceed = True
# Remaining balance = 1000.0
