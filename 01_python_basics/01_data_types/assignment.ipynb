# %% [markdown]
# # Assignment 1 - Student Registration System

# %%
student_name = input("enter student name")
age = int(input("enter their age"))
college_name = "BSSS"
course_name = "B.com"
percentage_obt = float(input("enter the percentage"))

print("-----Student Details-----")
print("name :",student_name)
print("age :",age)
print("College :",college_name)
print("Percentage :",percentage_obt,"%")
print("Reistration successful!")
# Out:
# -----Student Details-----
# name : Chandrapal
# age : 23
# College : BSSS
# Percentage : 65.55 %
# Reistration successful!
