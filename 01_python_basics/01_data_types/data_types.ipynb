# %%
age = 23
salary = 25500.75
name = "Chandrapal"
is_learning = True

print(age)
print(salary)
print(name)
print(is_learning)

print(type(age))
print(type(salary))
print(type(name))
print(type(is_learning))
# Out:
# 23
# 25500.75
# Chandrapal
# True
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
name = input("enter your name")
print("welcome")
print(name)
# Out:
# welcome
# Chandrapal

# %%
number = "100"

int(number)

print(type(number))
# Out:
# <class 'str'>
