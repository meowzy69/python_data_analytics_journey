# %% [markdown]
# # Practice set 1 - Data Types

# %%
# Store my name
name = "Chandrapal"
# store my age
age = 23
# store my height
height = 1.67
# store learning python in yes or no
python = True

print(name)
print(age)
print(height)
print(python)
# Out:
# Chandrapal
# 23
# 1.67
# True

# %%
city = "Bhopal"
Temperature = 34.5
Is_raining = False
print(city)
print(Temperature)
print(Is_raining)
# Out:
# Bhopal
# 34.5
# False

# %%
fav_club="Real Madrid"
print("My favorite football club is",fav_club)
# Out:
# My favorite football club is Real Madrid

# %%
name = input("enter your name")
print("Hello",name)
# Out:
# Hello Chandu

# %%
fav_city=input("enter your fav city")
print("I would like to visit",fav_city)
# Out:
# I would like to visit Tokoyo

# %%
age=int(input("enter your age"))
print("next year you will be",age+1)
# Out:
# next year you will be 24

# %%
n1=int(input("enter first number"))
n2=int(input("enter any number"))
print(n1+n2)
# Out:
# 115

# %%
Product_price=float(input("enter any number"))
print("Final price =",Product_price)
# Out:
# Final price = 499.99

# %%
Customer_name=input("enter your name")
customer_age=int(input("enter your age"))
purchase_amount=float(input("enter any number"))

print(Customer_name)
print(customer_age)
print(purchase_amount)
# Out:
# CP
# 25
# 456.0

# %%
customer_name=input("enter your name")
product_name=input("enter product name")
product_price=float(input("enter product price"))

print("----Bill----")
print("Customer :",customer_name)
print("Product :",product_name)
print("Price :","₹",product_price)
print("Thank you!")
# Out:
# ----Bill----
# Customer : Chandrapal
# Product : Keyboard
# Price : ₹ 999.99
# Thank you!
